# %% [markdown]
# <a href="https://colab.research.google.com/github/sivakumar6678/Googler_colab_Files/blob/master/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Python programming"
print(s)
print(s[0:3])
print(s[0:9])
print(s[0:9:1])
print(s[0:9:2])
print(s[::-1])
# Out:
# Python programming
# Pyt
# Python pr
# Python pr
# Pto r
# gnimmargorp nohtyP

# %%
s = "Python programming"
print(s)
print(s[0:3])
print(s[0:9])
print(s[0:9:1])
print(s[0:9:2])
print(s[::-1])
# Out:
# Python programming
# Pyt
# Python pr
# Python pr
# Pto r
# gnimmargorp nohtyP

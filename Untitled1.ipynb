# %% [markdown]
# <a href="https://colab.research.google.com/github/sivakumar6678/Googler_colab_Files/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Python programming"
print(s)
print(s[0:3])
print(s[0:9])
print(s[0:9:1])
print(s[0:9:2])
print(s[::-1])
# Out:
# Python programming
# Pyt
# Python pr
# Python pr
# Pto r
# gnimmargorp nohtyP

# %%
name = "python"
programming = "programming"
print(name + programming, end = "+\n")
print(name, programming, sep = "+")
print(len(name))
# Out:
# pythonprogramming+
# python+programming
# 6

# %%
a = "* "
print(a)
print(a * 6, end = "+")
print( 4 * 4)
# Out:
# *
# * * * * * * +16

# %%
name = "Python programming"
print(name)
print(name.lower())
print(name.title())
print(name.find("pro"))
print(name.find("test"))
print(name.count("m"))
print(name.startswith("Py"))
print(name.endswith("ing"))
age = "22.05"
print(age.isdigit())
print(name.isalpha())
print(age.isalnum())
# Out:
# Python programming
# python programming
# Python Programming
# 7
# -1
# 2
# True
# True
# False
# False
# False

# %%
name = " my name is  john    "
print(name)
print(name.strip())
print(name.lstrip())
print(name.rstrip())

print(name.replace("name", "age"))

print(name.split())
print(name.split(","))

name2 = "apple is , a fruit and banana is a fruit , fruit is good for health"
print(name2.split(","))
print(name2.split("is"))

myname = " john, ram, hir  "
print(myname.title().strip().split(","))
# Out:
#  my name is  john
# my name is  john
# my name is  john
#  my name is  john
#  my age is  john
# ['my', 'name', 'is', 'john']
# [' my name is  john    ']
# ['apple is ', ' a fruit and banana is a fruit ', ' fruit is good for health']
# ['apple ', ' , a fruit and banana ', ' a fruit , fruit ', ' good for health']
# ['John', ' Ram', ' Hir']

# %%
text = "python"

print(text.center(20, "-"))
print(text.ljust(20, "-"))
print(text.rjust(10,'0'))
print(text.zfill(10))
# Out:
# -------python-------
# python--------------
# 0000python
# 0000python

# %%
age = 20
# if age > 18 :
#   print("eligible")
# else:
#   print("not")

print("elgible") if age > 18 else print("not")
print("elgible "); print("not")
# Out:
# elgible
# not

# %%
a = 10
print(a)
print(id(a))

b = 20
print(b, id(b))

a = 20
print(a, id(a))
# Out:
# 10
# 11645640
# 20 11645960
# 20 11645960

# %%
students = ["Ravi", "Ananya", "Kiran", "Priya"]
print(type(students))
for student in students:
    print(student)
for i in range(len(students)):
  print(i, students[i])

for j in "students":
  print(j, end = " ")
# Out:
# <class 'list'>
# Ravi
# Ananya
# Kiran
# Priya
# 0 Ravi
# 1 Ananya
# 2 Kiran
# 3 Priya
# s t u d e n t s
